# %%
# q1 
#difference between '==' and 'is'
# '==' it checks that values are equal 
#'is' it checks if the variables refers to the same object
a=[4,5,6]
b=[4,5,6]
print(a==b)
print(a is b)
# Out:
# True
# False

# %%
#classify mutuable pr immutable
#list is mutuable
#tuple is immutuable
#set is mutuable
#dict is mutuable
#int is immutuable
#float is immutuable
#bool is immutuable
#frozenset is immutuable
# it makes programme safer or predictable as objct can not be changed after creating

# %%
#output of print(0.1+0.2==0.3) is False
#this happens because vaule stored internally of 0.1 or 0.2 is different 
print(0.1+0.2)
# this shows the answer=0.300000000000004 not 0.3 so the output is false
# Out:
# 0.30000000000000004

# %%
# they both are ordered but list is mutuable and tuple is immutuable
# 3 situations 
# days of week- it should be fixed ,not should be get modified sp we use tuple as it canot be change
#coordinates- in this coordinates should be fixed, the value of x and y can not be change
#dictionary keys - as keys are hashable so tuple is hasable as tuple is used

# %%
# dictionary searching value is O(1) on average because dictionary goes straight to the locker which contains the value , it knows the location ,it will take same time as 100 object or 1,00,000 object
# list seaching value is O(n) on wverage because it checks the object one by one , in the worst case you have to examine every valueit  meand 50 value , 50 examine
#hashtable
# dictionary use hash table internally it goes to the locker by using key-value
# list do not use hash so it has to go on each value one by one

# %%
matrix1 = [[0] * 3 for _ in range(3)]
matrix2 = [[0] * 3] * 3 
matrix1[0][0] = 99 
matrix2[0][0] = 99 
print(matrix1) 
print(matrix2)
# in second line *3 is outside the bracket this will print 99 in the matrix 2
# Out:
# [[99, 0, 0], [0, 0, 0], [0, 0, 0]]
# [[99, 0, 0], [99, 0, 0], [99, 0, 0]]

# %%
x = [1, 2, 3]
y = x 

x = x + [4] 
print("x =", x) 
print("y =", y) 
a = [1, 2, 3] 
b = a 
a += [4] 
print("a =", a) 
print("b =", b)
#x=x+[4] creates a new list and assigns it to the x 
#a+=[4] it extends the list
# Out:
# x = [1, 2, 3, 4]
# y = [1, 2, 3]
# a = [1, 2, 3, 4]
# b = [1, 2, 3, 4]

# %%
for i in range(5): 
    pass 
print(i) 
for j in range(0): 
    pass 
print(j)

# the output of range of i is [0,1,2,3,4] , when the loop ends it would give output 4
# j in range() will give error there no valurs loop dont run
# Out:
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       2     pass
#       3 print(i)
#       4 for j in range(0):
#       5     pass
# ----> 6 print(j)
#       7
#       8 # the output of range of i is [0,1,2,3,4] , when the loop ends it would give output 4
#       9 # j in range() will give error there no valurs loop dont run
#
# NameError: name 'j' is not defined

# %%
print("10" + "20") # in this '10'+'20' is  string so it would not add it will print as itis
print(10 + 20) # both are int so it will get add
print("10" * 3) # 10 is string and *3 will print 101010 
print(10 * "3")# 3 is string it will print 3 ten times

print(int("10") + 20)# it will convert 10 to int and +20 it will add the both
print("10" + 20) # give error str+int give erroe
# Out:
# 1020
# 30
# 101010
# 3333333333
# 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       3 print("10" * 3)
#       4 print(10 * "3")
#       5
#       6 print(int("10") + 20)
# ----> 7 print("10" + 20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(0 or 5)#0 gives false and 5 is truthy 
print(5 or 0)# it will give 5 as it is truthy
print(None or "hello")# none is falsy value so it print hello
print(0 and 5) # it will give 0 as it is falsy value and operator print first falsy value
print(5 and 10)# it will give 10 as first 5 is truth value it will check second so it print 10
print([] or "default") # empty list is falsy it print default
print([0] or "default")# it is non empty list print[0]
# Out:
# 5
# 5
# hello
# 0
# 10
# default
# [0]

# %%
#q-16

# a) arithmetic operations
a=10
b=20
a=a+b
b=a-b
a=a-b
print('a=',a)
print('b=',b)
# Out:
# a= 20
# b= 10

# %%
# b)XOR
a=10
b=20
a=a^b
b=a^b
a=a^b
print('a=',a)
print('b=',b)
# Out:
# a= 20
# b= 10

# %%
# c)  #pythonic
a = 10
b = 20

a, b = b, a

print(a)
print(b)
# Out:
# 20
# 10

# %%
price=float(input('enter the price'))
quantity=int(input('enter the quantity'))
total=price*quantity
gst=total*0.18

if final_total>500:
    delivery=40
else:
    delivery=0

final_total=total+gst+delivery

print('\n------------bill------------')
print('total=',total)
print('gst=',gst)
print('delivery=',delivery)
print('-------------------------------')
print('final_total=',final_total)
# Out:
# ------------bill------------
# total= 1250.0
# gst= 225.0
# delivery= 40
# -------------------------------
# final_total= 1515.0

# %%
# temperature converter
temperature=float(input('enter the value of temperature'))
unit=input('enter the unit c/f')



if unit=="c":
    fahrenheit = (temperature * 9 / 5) + 32
    print ('fahrenheit=',fahrenheit)
elif unit=="f":
    celsius = (temperature - 32) * 5 / 9
    print('celsius=',celsius)
else:
    print('invalid ')
# Out:
# fahrenheit= 77.0

# %%
num=int(input('enter a 4 digit number='))

digit1=num//1000
digit2=(num//100) %10
digit3=(num//10) %10
digit4=num%10

sum=digit1+digit2+digit3+digit4

print('sum=',sum)
# Out:
# sum= 10
